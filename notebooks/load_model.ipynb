# %%
import torch
import os

from config import ROOT

model_path = os.path.join(ROOT, "outputs", "models", "26_07_08_best.pt")
model = torch.load(model_path, map_location=torch.device('cpu'))

print(model["val_top1_acc"])
